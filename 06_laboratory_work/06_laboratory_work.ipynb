# %% [markdown]
# # Лабораторная работа №6: ONNX

# %% [markdown]
# **Задача:** выгрузить модель машинного обучения в формате ONNX - [Convert your PyTorch training model to ONNX (Microsoft course)](https://learn.microsoft.com/en-us/windows/ai/windows-ml/tutorials/pytorch-convert-model).
#
# **Источник данных:** `torchvision.datasets.CIFAR10`

# %% [markdown]
# <div style="background-color: blue; height: 2px; margin: 10px 0;"></div>

# %% [markdown]
# ## 1 ONNX

# %% [markdown]
# Установка необходимых библиотек:

# %%
# %%capture no-display
# !pip install onnx

# %% [markdown]
# Импорт модуля:

# %%
import main
# Out:
# Files already downloaded and verified
# The number of images in a training set is:  50000
# Files already downloaded and verified
# The number of images in a test set is:  10000
# The number of batches per epoch is:  5000

# %% [markdown]
# Вызов функции `main()`:

# %%
main.main()
# Out:
# The model will be running on cuda device
#
# [1,  1000] loss: 1.781
# [1,  2000] loss: 1.478
# [1,  3000] loss: 1.316
# [1,  4000] loss: 1.208
# [1,  5000] loss: 1.156
# For epoch 1 the test accuracy over the whole test set is 63 %
#
# Finished Training
# Accuracy of plane : 55 %
# Accuracy of   car : 75 %
# Accuracy of  bird : 56 %
# Accuracy of   cat : 35 %
# Accuracy of  deer : 63 %
# Accuracy of   dog : 47 %
# Accuracy of  frog : 72 %
# Accuracy of horse : 66 %
# Accuracy of  ship : 84 %
# Accuracy of truck : 72 %
# Real labels:    cat  ship  ship plane  frog  frog   car  frog   cat   car
# Predicted:    cat  ship  ship  ship  frog  frog   car  frog   cat truck
# ============= Diagnostic Run torch.onnx.export version 2.0.1+cu117 =============
# verbose: False, log level: Level.ERROR
# ======================= 0 NONE 0 NOTE 0 WARNING 0 ERROR ========================
#
#
#
# Model has been converted to ONNX

# %% [markdown]
# <div style="background-color: blue; height: 2px; margin: 10px 0;"></div>

# %% [markdown]
# ## 2 Общий вывод

# %% [markdown]
# Было произведено обучение модели на наборе данных CIFAR10. Сама модель была конвертирована в формат ONNX для дальнейшего импорта в Unity.

# %% [markdown]
# <div style="text-align: center; font-size: 20px; padding: 15px 0;">
#     <a href="#Лабораторная-работа-№6:-ONNX" data-toc-modified-id="Лабораторная-работа-№6:-ONNX" style="text-decoration: none; color: #296eaa; border: 2px dashed #296eaa; opacity: 0.8; border-radius: 3px; padding: 10px 80px;">
#         В начало файла ↑
#     </a>
# </div>
