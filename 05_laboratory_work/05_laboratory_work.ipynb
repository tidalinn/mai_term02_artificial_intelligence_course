# %% [markdown]
# # Лабораторная работа №5: RANSAC

# %% [markdown]
# **Задача:** запрограммировать устойчивый к зашумлённым исходным данным метод оценки модели на основе случайных выборок.
#
# **Источник данных:** сгенерированные точки

# %% [markdown]
# <div style="background-color: blue; height: 2px; margin: 10px 0;"></div>

# %% [markdown]
# ## 2 RANSAC

# %% [markdown]
# Вызов функции `main()`:

# %%
from main import main

# %% [markdown]
# <div style="background-color: blue; height: 2px; margin: 10px 0;"></div>

# %% [markdown]
# ## 3 Общий вывод

# %% [markdown]
# Были реализованы классы `PointGenerator` (формирование разброса точек), `Line` (формирование линии) и `RANSAC` (оценка шума) с возможностью тестирования как в Jupyter notebook, так и при вызове файла `main.py` через командную строку.

# %% [markdown]
# <div style="text-align: center; font-size: 20px; padding: 15px 0;">
#     <a href="#Лабораторная-работа-№5:-RANSAC " data-toc-modified-id="Лабораторная-работа-№5:-RANSAC" style="text-decoration: none; color: #296eaa; border: 2px dashed #296eaa; opacity: 0.8; border-radius: 3px; padding: 10px 80px;">
#         В начало файла ↑
#     </a>
# </div>
