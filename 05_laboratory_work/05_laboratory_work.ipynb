# %% [markdown]
# # Лабораторная работа №5: RANSAC

# %% [markdown]
# **Задача:** запрограммировать устойчивый к зашумлённым исходным данным метод оценки модели на основе случайных выборок.
#
# **Источник данных:** сгенерированные точки

# %% [markdown]
# <div style="background-color: blue; height: 2px; margin: 10px 0;"></div>

# %% [markdown]
# ## 1 RANSAC

# %% [markdown]
# Импорт модуля:

# %%
import main

# %% [markdown]
# Вызов функции `main()`:

# %%
main.main()
# Out:
# kx + b + epsilon: 1.5x + 2.0 + 0.3
#
# Доля НЕ принадлежащих к прямой точек: 0.1
# Доля принадлежащих к прямой точек: 0.8
#
# Порог НЕ принадлежности точек к прямой: 0.3
# Порог принадлежности точек к прямой: 0.35
# kx + b + epsilon: 1.5x + 1.0 + 0.8
#
# Доля НЕ принадлежащих к прямой точек: 0.5
# Доля принадлежащих к прямой точек: 0.5
#
# Порог НЕ принадлежности точек к прямой: 0.8
# Порог принадлежности точек к прямой: 0.85
# kx + b + epsilon: 1.7x + 2.2 + 0.3
#
# Доля НЕ принадлежащих к прямой точек: 0.3
# Доля принадлежащих к прямой точек: 0.7
#
# Порог НЕ принадлежности точек к прямой: 0.3
# Порог принадлежности точек к прямой: 0.35

# %% [markdown]
# <div style="background-color: blue; height: 2px; margin: 10px 0;"></div>

# %% [markdown]
# ## 2 Общий вывод

# %% [markdown]
# Были реализованы классы `PointGenerator` (формирование разброса точек), `Line` (формирование линии) и `RANSAC` (оценка шума), результат работы совокупности которых можно продемонстрировать при вызове файла `main.py`.
#
# Стоит отметить, что алгоритм ведёт себя более стабильно в следующих случаях:
#
# * при малой доле НЕ принадлежащих к линии точек и большей доли принадлежащих.
# * при небольшом пороге (радиусе) принадлежности и НЕ принадлежности точек к прямой.

# %% [markdown]
# <div style="text-align: center; font-size: 20px; padding: 15px 0;">
#     <a href="#Лабораторная-работа-№5:-RANSAC " data-toc-modified-id="Лабораторная-работа-№5:-RANSAC" style="text-decoration: none; color: #296eaa; border: 2px dashed #296eaa; opacity: 0.8; border-radius: 3px; padding: 10px 80px;">
#         В начало файла ↑
#     </a>
# </div>
